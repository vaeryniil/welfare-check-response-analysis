# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
#this line forces it to show all the columns instead of only the first and last columns
pd.set_option('display.max_columns', None)

# %%
#reading in Eugene emergency response data 2015-2025

CAD2015 = pd.read_csv("data/Eugene_CAD_data_noloc/EugeneCAD2015noloc.csv",na_values='NULL')
CAD2016 = pd.read_csv("data/Eugene_CAD_data_noloc/EugeneCAD2016noloc.csv",na_values='NULL')
CAD2017 = pd.read_csv("data/Eugene_CAD_data_noloc/EugeneCAD2017noloc.csv",na_values='NULL')
CAD2018 = pd.read_csv("data/Eugene_CAD_data_noloc/EugeneCAD2018noloc.csv",na_values='NULL')
CAD2019 = pd.read_csv("data/Eugene_CAD_data_noloc/EugeneCAD2019noloc.csv",na_values='NULL')
CAD2020 = pd.read_csv("data/Eugene_CAD_data_noloc/EugeneCAD2020noloc.csv",na_values='NULL')
CAD2021 = pd.read_csv("data/Eugene_CAD_data_noloc/EugeneCAD2021noloc.csv",na_values='NULL')
CAD2022 = pd.read_csv("data/Eugene_CAD_data_noloc/EugeneCAD2022noloc.csv",na_values='NULL')
CAD2023 = pd.read_csv("data/Eugene_CAD_data_noloc/EugeneCAD2023noloc.csv",na_values='NULL')
CAD2024 = pd.read_csv("data/Eugene_CAD_data_noloc/EugeneCAD2024noloc.csv",na_values='NULL')
CAD2025 = pd.read_csv("data/Eugene_CAD_data_noloc/EugeneCAD2025noloc.csv",na_values='NULL')
# Out:
# /var/folders/0y/gklqyv_101130y1ly46wc5wm0000gn/T/ipykernel_24977/2484449190.py:9: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   CAD2021 = pd.read_csv("data/Eugene_CAD_data_noloc/EugeneCAD2021noloc.csv",na_values='NULL')
# /var/folders/0y/gklqyv_101130y1ly46wc5wm0000gn/T/ipykernel_24977/2484449190.py:13: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   CAD2025 = pd.read_csv("data/Eugene_CAD_data_noloc/EugeneCAD2025noloc.csv",na_values='NULL')

# %%
#example
CAD2015.head()
# Out:
#      yr agency service   inci_id                 calltime  case_id callsource  \
# 0  2015   EPD     LAW   15000001  2015-01-01 00:00:00.000      NaN       SELF
# 1  2015   EPD     LAW   15000002  2015-01-01 00:00:44.000      NaN       SELF
# 2  2015   EPD     LAW   15000003  2015-01-01 00:01:05.000      NaN      PHONE
# 3  2015   EPD     LAW   15000007  2015-01-01 00:03:16.000      NaN       W911
# 4  2015   EPD     LAW   15000010  2015-01-01 00:03:34.000      NaN       SELF
#
#               nature closecode     closed_as  secs_to_disp  secs_to_arrv  \
# 0        PERSON STOP      ASST      ASSISTED           0.0           0.0
# 1              FIGHT      RSLV      RESOLVED           0.0           0.0
# 2      CHECK WELFARE      ASST      ASSISTED         708.0        1094.0
# 3        SHOTS FIRED      PCHK  PATROL CHECK         277.0         576.0
# 4  ILLEGAL FIREWORKS      ADVI       ADVISED           0.0           0.0
#
#    secs_to_close  disp  arrv priority primeunit  units_dispd  units_arrived
# 0            217     1     1        6   _5E48              1              1
# 1           2114     1     1        P   _3F65              4              2
# 2           1538     1     1        5   _3J79              1              1
# 3            891     1     1        3   _5E48              2              2
# 4            150     1     1        5   _5K97              1              1

# %%
#making sure that welfare checks are only coded one way in each data set:
#CAD2015['nature'].unique() #'CHECK WELFARE'
#CAD2016['nature'].unique() #'CHECK WELFARE'
#CAD2017['nature'].unique() #'CHECK WELFARE'
#CAD2018['nature'].unique() #'CHECK WELFARE'
#CAD2019['nature'].unique() #'CHECK WELFARE'
#CAD2020['nature'].unique() #'CHECK WELFARE'
#CAD2021['nature'].unique() #'CHECK WELFARE'
#CAD2025['nature'].unique() #'CHECK WELFARE'
#Yes. There's nothing else similar that's in that category (and no typos).
#So I can filter by a call nature of CHECK WELFARE

# %%
#Note: other types of calls sometimes ended in a welfare check. 
#Did missing person reports or similar?
CAD2015[CAD2015['nature'] == 'MISSING PERSON']['closed_as'].unique() #no
CAD2015[CAD2015['nature'] == 'LOCATION WANTED SUBJECT']['closed_as'].unique() #no
CAD2015[CAD2015['nature'] == 'LOCATE MISSING PERSON']['closed_as'].unique() #no
CAD2015[CAD2015['nature'] == 'CITIZEN CONTACT']['closed_as'].unique() #no
CAD2015[CAD2015['nature'] == 'OVERDUE SUBJECT']['closed_as'].unique() #no
CAD2015[CAD2015['nature'] == 'REQUEST ASSISTANCE']['closed_as'].unique() #no
CAD2015[CAD2015['nature'] == 'VACATION CHECK']['closed_as'].unique() #no
CAD2015[CAD2015['nature'] == 'ILL SUBJECT']['closed_as'].unique() #no
CAD2015[CAD2015['nature'] == 'COMMUNITY POLICING ACTIVITY']['closed_as'].unique() #no

CAD2018[CAD2018['nature'] == 'EMERGENCY LOCATE REQUEST']['closed_as'].unique() #no
# Out:
# array(['REFERRED TO OTHER AGENCY', 'PUBLIC WORKS'], dtype=object)

# %%
#filtering each of the data sets to only include welfare check calls (requests for a welfare check)
WELFARE2015 = CAD2015[CAD2015['nature'] == 'CHECK WELFARE']
WELFARE2016 = CAD2016[CAD2016['nature'] == 'CHECK WELFARE']
WELFARE2017 = CAD2017[CAD2017['nature'] == 'CHECK WELFARE']
WELFARE2018 = CAD2018[CAD2018['nature'] == 'CHECK WELFARE']
WELFARE2019 = CAD2019[CAD2019['nature'] == 'CHECK WELFARE']
WELFARE2020 = CAD2020[CAD2020['nature'] == 'CHECK WELFARE']
WELFARE2021 = CAD2021[CAD2021['nature'] == 'CHECK WELFARE']
WELFARE2022 = CAD2022[CAD2022['nature'] == 'CHECK WELFARE']
WELFARE2023 = CAD2023[CAD2023['nature'] == 'CHECK WELFARE']
WELFARE2024 = CAD2024[CAD2024['nature'] == 'CHECK WELFARE']
WELFARE2025 = CAD2025[CAD2025['nature'] == 'CHECK WELFARE']

# %%
#putting all WELFARE data frames 2015-25 into a single data frame
frames = [WELFARE2015, WELFARE2016, WELFARE2017, WELFARE2018, WELFARE2019, WELFARE2020,
          WELFARE2021, WELFARE2022, WELFARE2023, WELFARE2024, WELFARE2025]

WELFARE = pd.concat(frames)
WELFARE
# Out:
#           yr agency service   inci_id                 calltime case_id  \
# 2       2015   EPD     LAW   15000003  2015-01-01 00:01:05.000     NaN
# 27      2015   EPD     LAW   15000052  2015-01-01 00:38:37.000     NaN
# 47      2015   EPD     LAW   15000092  2015-01-01 01:28:40.000     NaN
# 55      2015   EPD     LAW   15000107  2015-01-01 01:41:40.000     NaN
# 186     2015   EPD     LAW   15000435  2015-01-01 15:09:21.000     NaN
# ...      ...    ...     ...       ...                      ...     ...
# 117254  2025   EPD     LAW   25327100  2025-12-31 17:12:02.000     NaN
# 117265  2025   EPD     LAW   25327137  2025-12-31 17:56:18.000     NaN
# 117284  2025   EPD     LAW   25327208  2025-12-31 20:23:13.000     NaN
# 117295  2025   EPD     LAW   25327228  2025-12-31 20:50:01.000     NaN
# 117301  2025   EPD     LAW   25327245  2025-12-31 21:11:50.000     NaN
#
#        callsource         nature closecode                closed_as  \
# 2           PHONE  CHECK WELFARE      ASST                 ASSISTED
# 27          PHONE  CHECK WELFARE      ASST                 ASSISTED
# 47          PHONE  CHECK WELFARE      UTL          UNABLE TO LOCATE
# 55          PHONE  CHECK WELFARE      ASST                 ASSISTED
# 186         PHONE  CHECK WELFARE      ASST                 ASSISTED
# ...           ...            ...       ...                      ...
# 117254      PHONE  CHECK WELFARE      DDIS  DISREGARDED BY DISPATCH
# 117265      PHONE  CHECK WELFARE      UTL          UNABLE TO LOCATE
# 117284      PHONE  CHECK WELFARE      WELC       WELFARE CHECK DONE
# 117295       W911  CHECK WELFARE      DIS                 DISREGARD
# 117301       W911  CHECK WELFARE      WELC       WELFARE CHECK DONE
#
#         secs_to_disp  secs_to_arrv  secs_to_close  disp  arrv priority  \
# 2              708.0        1094.0           1538     1     1        5
# 27            2402.0        2941.0           3594     1     1        5
# 47            1305.0        1524.0           1824     1     1        5
# 55             600.0         926.0           1285     1     1        5
# 186           3018.0        3605.0           4369     1     1        7
# ...              ...           ...            ...   ...   ...      ...
# 117254           NaN           NaN           4147     0     0        4
# 117265        5655.0        6292.0           8294     1     1        3
# 117284        2828.0        3001.0           3451     1     1        3
# 117295         354.0         740.0            818     1     1        3
# 117301        3433.0        4208.0           5682     1     1        3
#
#        primeunit  units_dispd  units_arrived  month
# 2        _3J79              1              1    NaN
# 27       _3J79              1              1    NaN
# 47       _5B44              1              1    NaN
# 55       _3J79              1              1    NaN
# 186      _3J79              1              1    NaN
# ...          ...          ...            ...    ...
# 117254       NaN            0              0   12.0
# 117265   _4U72              2              2   12.0
# 117284   _5E56              2              2   12.0
# 117295   _4U72              2              2   12.0
# 117301   _6B36              1              1   12.0
#
# [76670 rows x 20 columns]

# %%
#reset the index
WELFARE.reset_index(inplace=True)

# %%
#Strip whitespace and leading "_" from the primeunit column
WELFARE['primeunit'] = WELFARE['primeunit'].str.strip()
WELFARE['primeunit'] = WELFARE['primeunit'].str.strip("_")

# %%
#sanity check: what are the shapes of the by-year data frames?
WELFARE2015.shape #(4498, 19)
WELFARE2016.shape #(6964, 19)
WELFARE2017.shape #(7392, 19)
WELFARE2018.shape #(7924, 19)
WELFARE2019.shape #(8629, 19)
WELFARE2020.shape #(9138, 19)
WELFARE2021.shape #(10341, 19)
WELFARE2022.shape #(6322, 19)
WELFARE2023.shape #(4791, 19)
WELFARE2024.shape #(4695, 19)
WELFARE2025.shape #(5976, 20)
# Out:
# (5976, 20)

# %%
#making sure the numbers add up
WELFARE2015.shape[0] + WELFARE2016.shape[0] + WELFARE2017.shape[0] + WELFARE2018.shape[0] + WELFARE2019.shape[0] + WELFARE2020.shape[0] + WELFARE2021.shape[0] + WELFARE2022.shape[0] + WELFARE2023.shape[0] + WELFARE2024.shape[0] + WELFARE2025.shape[0]
#they do
# Out:
# 76670

# %%
#Converting data strings to datetime objects
#type(WELFARE['calltime'][0]) #it's a string before conversion
WELFARE['calltime'] = WELFARE['calltime'].apply(
    lambda x: dt.datetime.strptime(x,'%Y-%m-%d %H:%M:%S.%f'))

# %%
#test
type(WELFARE['calltime'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#looking at the work so far
WELFARE
# Out:
#         index    yr agency service   inci_id            calltime case_id  \
# 0           2  2015   EPD     LAW   15000003 2015-01-01 00:01:05     NaN
# 1          27  2015   EPD     LAW   15000052 2015-01-01 00:38:37     NaN
# 2          47  2015   EPD     LAW   15000092 2015-01-01 01:28:40     NaN
# 3          55  2015   EPD     LAW   15000107 2015-01-01 01:41:40     NaN
# 4         186  2015   EPD     LAW   15000435 2015-01-01 15:09:21     NaN
# ...       ...   ...    ...     ...       ...                 ...     ...
# 76665  117254  2025   EPD     LAW   25327100 2025-12-31 17:12:02     NaN
# 76666  117265  2025   EPD     LAW   25327137 2025-12-31 17:56:18     NaN
# 76667  117284  2025   EPD     LAW   25327208 2025-12-31 20:23:13     NaN
# 76668  117295  2025   EPD     LAW   25327228 2025-12-31 20:50:01     NaN
# 76669  117301  2025   EPD     LAW   25327245 2025-12-31 21:11:50     NaN
#
#       callsource         nature closecode                closed_as  \
# 0          PHONE  CHECK WELFARE      ASST                 ASSISTED
# 1          PHONE  CHECK WELFARE      ASST                 ASSISTED
# 2          PHONE  CHECK WELFARE      UTL          UNABLE TO LOCATE
# 3          PHONE  CHECK WELFARE      ASST                 ASSISTED
# 4          PHONE  CHECK WELFARE      ASST                 ASSISTED
# ...          ...            ...       ...                      ...
# 76665      PHONE  CHECK WELFARE      DDIS  DISREGARDED BY DISPATCH
# 76666      PHONE  CHECK WELFARE      UTL          UNABLE TO LOCATE
# 76667      PHONE  CHECK WELFARE      WELC       WELFARE CHECK DONE
# 76668       W911  CHECK WELFARE      DIS                 DISREGARD
# 76669       W911  CHECK WELFARE      WELC       WELFARE CHECK DONE
#
#        secs_to_disp  secs_to_arrv  secs_to_close  disp  arrv priority  \
# 0             708.0        1094.0           1538     1     1        5
# 1            2402.0        2941.0           3594     1     1        5
# 2            1305.0        1524.0           1824     1     1        5
# 3             600.0         926.0           1285     1     1        5
# 4            3018.0        3605.0           4369     1     1        7
# ...             ...           ...            ...   ...   ...      ...
# 76665           NaN           NaN           4147     0     0        4
# 76666        5655.0        6292.0           8294     1     1        3
# 76667        2828.0        3001.0           3451     1     1        3
# 76668         354.0         740.0            818     1     1        3
# 76669        3433.0        4208.0           5682     1     1        3
#
#       primeunit  units_dispd  units_arrived  month
# 0          3J79            1              1    NaN
# 1          3J79            1              1    NaN
# 2          5B44            1              1    NaN
# 3          3J79            1              1    NaN
# 4          3J79            1              1    NaN
# ...         ...          ...            ...    ...
# 76665       NaN            0              0   12.0
# 76666      4U72            2              2   12.0
# 76667      5E56            2              2   12.0
# 76668      4U72            2              2   12.0
# 76669      6B36            1              1   12.0
#
# [76670 rows x 21 columns]

# %%
#want to extract the month for every row, not just the 2025 ones
WELFARE['month'] = WELFARE['calltime'].dt.month
WELFARE['year'] = WELFARE['calltime'].dt.year

# %%
#checking for duplicated rows
sum(WELFARE.duplicated())
#according to this, there are none
# Out:
# 0

# %%
#how many NaNs have I got?
WELFARE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76670 entries, 0 to 76669
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          76670 non-null  int64
#  1   yr             76670 non-null  int64
#  2   agency         76670 non-null  object
#  3   service        76670 non-null  object
#  4   inci_id        76670 non-null  int64
#  5   calltime       76670 non-null  datetime64[ns]
#  6   case_id        3644 non-null   object
#  7   callsource     76670 non-null  object
#  8   nature         76670 non-null  object
#  9   closecode      76670 non-null  object
#  10  closed_as      76645 non-null  object
#  11  secs_to_disp   64900 non-null  float64
#  12  secs_to_arrv   59971 non-null  float64
#  13  secs_to_close  76670 non-null  int64
#  14  disp           76670 non-null  int64
#  15  arrv           76670 non-null  int64
#  16  priority       76670 non-null  object
#  17  primeunit      68302 non-null  object
#  18  units_dispd    76670 non-null  int64
#  19  units_arrived  76670 non-null  int64
#  20  month          76670 non-null  int32
#  21  year           76670 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(8), object(9)
# memory usage: 12.3+ MB

# %%
#how many missing unit values?
76670 - 68302
#8368 null values in the primeunit column
# Out:
# 8368

# %%
#I have a sneaking suspicion that these null values occur when dispatch doesn't send 
#a unit. This is _very_ important, so I may need to fill these in somehow, not discard them.
disregarded = WELFARE[WELFARE['closed_as'] == 'DISREGARDED BY DISPATCH']
disregarded.shape #there are only 942 of these, and not all of them have no data for primeunit!
#so there are other things going on
disregarded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 942 entries, 155 to 76665
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          942 non-null    int64
#  1   yr             942 non-null    int64
#  2   agency         942 non-null    object
#  3   service        942 non-null    object
#  4   inci_id        942 non-null    int64
#  5   calltime       942 non-null    datetime64[ns]
#  6   case_id        0 non-null      object
#  7   callsource     942 non-null    object
#  8   nature         942 non-null    object
#  9   closecode      942 non-null    object
#  10  closed_as      942 non-null    object
#  11  secs_to_disp   65 non-null     float64
#  12  secs_to_arrv   10 non-null     float64
#  13  secs_to_close  942 non-null    int64
#  14  disp           942 non-null    int64
#  15  arrv           942 non-null    int64
#  16  priority       942 non-null    object
#  17  primeunit      623 non-null    object
#  18  units_dispd    942 non-null    int64
#  19  units_arrived  942 non-null    int64
#  20  month          942 non-null    int32
#  21  year           942 non-null    int32
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(8), object(9)
# memory usage: 161.9+ KB

# %%
disregarded['primeunit'].unique()
# Out:
# array(['CAHOT', nan, 'CNTR', '3J78', '3J79', '4J79', '2E39', '1J77',
#        '4E14'], dtype=object)

# %%
#total 'DISREGARDED BY DISPATCH' where primeunit is null:
942-623
#there are 319 null values. That's only a small fraction of them. How small a fraction?
# Out:
# 319

# %%
#percent of total primeunit nulls that were closed as disregarded by dispatch:
(319 / 8368) * 100
#3.8%. Not that high. What else is going on?
# Out:
# 3.812141491395794

# %%
#I want to isolate all the rows where the primeunit is Nan. 
#This is to explore what's going on with these null values more carefully
nullprimeunit = WELFARE[WELFARE['primeunit'].isnull()]

# %%
nullprimeunit
# Out:
#         index    yr agency service   inci_id            calltime case_id  \
# 25        929  2015   EPD     LAW   15002311 2015-01-03 20:40:21     NaN
# 28       1099  2015   EPD     LAW   15002732 2015-01-04 13:50:21     NaN
# 30       1185  2015   EPD     LAW   15002961 2015-01-04 20:07:10     NaN
# 35       1307  2015   EPD     LAW   15003287 2015-01-05 11:30:36     NaN
# 36       1345  2015   EPD     LAW   15003378 2015-01-05 13:39:36     NaN
# ...       ...   ...    ...     ...       ...                 ...     ...
# 76630  116647  2025   EPD     LAW   25325283 2025-12-29 10:00:40     NaN
# 76636  116711  2025   EPD     LAW   25325456 2025-12-29 14:37:57     NaN
# 76654  117052  2025   EPD     LAW   25326559 2025-12-31 00:08:55     NaN
# 76664  117253  2025   EPD     LAW   25327096 2025-12-31 17:07:58     NaN
# 76665  117254  2025   EPD     LAW   25327100 2025-12-31 17:12:02     NaN
#
#       callsource         nature closecode                 closed_as  \
# 25         PHONE  CHECK WELFARE      DIS                  DISREGARD
# 28          E911  CHECK WELFARE      INFO          INFORMATION ONLY
# 30          E911  CHECK WELFARE      DIS                  DISREGARD
# 35         PHONE  CHECK WELFARE      DIS                  DISREGARD
# 36         PHONE  CHECK WELFARE      DIS                  DISREGARD
# ...          ...            ...       ...                       ...
# 76630       W911  CHECK WELFARE      DDIS   DISREGARDED BY DISPATCH
# 76636      PHONE  CHECK WELFARE      REL   REFERRED TO OTHER AGENCY
# 76654      PHONE  CHECK WELFARE      DIS                  DISREGARD
# 76664       W911  CHECK WELFARE      RSLV                  RESOLVED
# 76665      PHONE  CHECK WELFARE      DDIS   DISREGARDED BY DISPATCH
#
#        secs_to_disp  secs_to_arrv  secs_to_close  disp  arrv priority  \
# 25              NaN           NaN           1015     0     0        3
# 28              NaN           NaN            809     0     0        4
# 30              NaN           NaN           2251     0     0        3
# 35              NaN           NaN           1247     0     0        4
# 36              NaN           NaN            665     0     0        3
# ...             ...           ...            ...   ...   ...      ...
# 76630           NaN           NaN            332     0     0        3
# 76636           NaN           NaN            213     0     0        P
# 76654           NaN           NaN           1612     0     0        3
# 76664           NaN           NaN           4161     0     0        3
# 76665           NaN           NaN           4147     0     0        4
#
#       primeunit  units_dispd  units_arrived  month  year
# 25          NaN            0              0      1  2015
# 28          NaN            0              0      1  2015
# 30          NaN            0              0      1  2015
# 35          NaN            0              0      1  2015
# 36          NaN            0              0      1  2015
# ...         ...          ...            ...    ...   ...
# 76630       NaN            0              0     12  2025
# 76636       NaN            0              0     12  2025
# 76654       NaN            0              0     12  2025
# 76664       NaN            0              0     12  2025
# 76665       NaN            0              0     12  2025
#
# [8368 rows x 22 columns]

# %%
#oh! DISREGARDED BY DISPATCH isn't the only way for a call to be disregarded
nullprimeunit['closed_as'].unique()
# Out:
# array(['DISREGARD', 'INFORMATION ONLY', 'REFERRED TO OTHER AGENCY',
#        'RESOLVED', 'CALLER WILL CALL BACK', 'DISREGARDED BY DISPATCH',
#        'DISREGARDED BY PATROL SUPERVISOR', nan,
#        'RELAYED TO UNIVERSITY OF OREGON POLICE',
#        'ACCIDENTALLY CHOSE NEW EVENT', 'UNABLE TO DISPATCH',
#        'RELAYED TO LANE COUNTY SHERIFFS OFFICE', 'UNABLE TO LOCATE',
#        'QUALITY OF LIFE - NO DISPATCH', 'RELAYED TO OREGON STATE POLICE',
#        'RELAYED TO JUNCTION CITY DISPATCH', 'CALLER CALLED BACK',
#        'GONE ON ARRIVAL', 'ASSISTED', 'ARREST',
#        'CITED IN LIEU OF CUSTODY', 'REPORT TAKEN', 'ADVISED',
#        'RELAYED TO BENTON COUNTY', 'TRANSPORT MADE', 'PUBLIC WORKS',
#        'FOLLOW UP INVESTIGATION', 'WELFARE CHECK DONE', 'UNFOUNDED',
#        'ABANDONED VEHICLE ', 'RELAYED TO LINN COUNTY 911'], dtype=object)

# %%
nullprimeunit['units_dispd'].unique()
# Out:
# array([0, 1, 3, 4, 2, 5])

# %%
sns.histplot(data=nullprimeunit,x = 'units_dispd')
# Out:
# <Axes: xlabel='units_dispd', ylabel='Count'>

# %%
#I want to figure out how many rows have units_dispd > 0
nullprimeunit[nullprimeunit['units_dispd'] > 0]
# Out:
#         index    yr agency service   inci_id            calltime case_id  \
# 130      4085  2015   EPD     LAW   15010264 2015-01-14 09:39:39     NaN
# 213      6452  2015   EPD     LAW   15015996 2015-01-21 16:03:08     NaN
# 302      9330  2015   EPD     LAW   15022713 2015-01-29 22:24:00     NaN
# 320      9880  2015   EPD     LAW   15023902 2015-01-31 11:17:40     NaN
# 383     11266  2015   EPD     LAW   15027379 2015-02-04 18:41:42     NaN
# ...       ...   ...    ...     ...       ...                 ...     ...
# 75598   97887  2025   EPD     LAW   25271082 2025-10-23 21:05:40     NaN
# 75872  102747  2025   EPD     LAW   25285117 2025-11-08 17:00:11     NaN
# 75997  105374  2025   EPD     LAW   25292821 2025-11-18 12:20:04     NaN
# 76014  105691  2025   EPD     LAW   25293747 2025-11-19 13:44:54     NaN
# 76555  115454  2025   EPD     LAW   25321933 2025-12-24 10:08:01     NaN
#
#       callsource         nature closecode                 closed_as  \
# 130        PHONE  CHECK WELFARE      RSLV                  RESOLVED
# 213        PHONE  CHECK WELFARE      RSLV                  RESOLVED
# 302        PHONE  CHECK WELFARE      REL   REFERRED TO OTHER AGENCY
# 320        PHONE  CHECK WELFARE      DIS                  DISREGARD
# 383        PHONE  CHECK WELFARE                                 NaN
# ...          ...            ...       ...                       ...
# 75598      PHONE  CHECK WELFARE      DDIS   DISREGARDED BY DISPATCH
# 75872       W911  CHECK WELFARE      DIS                  DISREGARD
# 75997      PHONE  CHECK WELFARE      REL   REFERRED TO OTHER AGENCY
# 76014      PHONE  CHECK WELFARE      DIS                  DISREGARD
# 76555      PHONE  CHECK WELFARE      RSLV                  RESOLVED
#
#        secs_to_disp  secs_to_arrv  secs_to_close  disp  arrv priority  \
# 130          7354.0        7711.0           7981     1     1        5
# 213          9341.0        9845.0          13761     1     1        4
# 302          3398.0           NaN          11967     1     0        3
# 320          8479.0        8725.0           8904     1     1        7
# 383          1122.0        1360.0           6328     1     1        5
# ...             ...           ...            ...   ...   ...      ...
# 75598         341.0           NaN          44668     1     0        4
# 75872        4208.0        4208.0           4394     1     1        3
# 75997        1024.0           NaN           1943     1     0        3
# 76014         527.0           NaN            709     1     0        3
# 76555         132.0           NaN            159     1     0        3
#
#       primeunit  units_dispd  units_arrived  month  year
# 130         NaN            1              0      1  2015
# 213         NaN            3              2      1  2015
# 302         NaN            4              0      1  2015
# 320         NaN            1              1      1  2015
# 383         NaN            4              3      2  2015
# ...         ...          ...            ...    ...   ...
# 75598       NaN            3              1     10  2025
# 75872       NaN            1              0     11  2025
# 75997       NaN            2              0     11  2025
# 76014       NaN            2              0     11  2025
# 76555       NaN            1              0     12  2025
#
# [419 rows x 22 columns]

# %%
#So. The proportion of nature == 'WELFARE CHECK' calls
# that have no 'primeunit' and yet say that at least one was sent out is 
#0.00546. That's not very many. I'm going to drop these rows. 
#IMPORTANT: will need to put that as an assumption
419 / 76670
# Out:
# 0.005464979783487674

# %% [markdown]
# Great. So. We've read in the Eugene CAD files for 2015-2025, filtered them for call nature of welfare check only, and combined them into a single df called WELFARE. We've also converted the calltime to a datetime object, and stripped out the whitespace and leading "_" from the primeunit column. Now we need to add an extra column that represents whether a call was answered by CAHOOTS, EPD, or if no unit was sent. In order to do this, I first need to drop every row where primeunit is nan and the # of units sent out is > 0. The resultant data frame should be 76251 rows long. Okay? Okay.

# %%
#dropping rows where the primeunit is a null value and more than 0 units were dispatched
welfare = WELFARE[(WELFARE['primeunit'].notna()) | (WELFARE['units_dispd'] == 0)]

# %%
#welfare
#this worked. It's 76251 rows :)

# %%
#Adding a column saying whether cahoots, epd, or neither answered the call

welfare["Institution"] = np.where(    
    welfare["primeunit"].str.contains("J|CAH", na=False),    
    "CAHOOTS",    
    np.where(        
        welfare["primeunit"].isna(),        
        "Neither",        
        "EPD"    
    )
)
# Out:
# /var/folders/0y/gklqyv_101130y1ly46wc5wm0000gn/T/ipykernel_24977/2384706366.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   welfare["Institution"] = np.where(

# %%
welfare
# Out:
#         index    yr agency service   inci_id            calltime case_id  \
# 0           2  2015   EPD     LAW   15000003 2015-01-01 00:01:05     NaN
# 1          27  2015   EPD     LAW   15000052 2015-01-01 00:38:37     NaN
# 2          47  2015   EPD     LAW   15000092 2015-01-01 01:28:40     NaN
# 3          55  2015   EPD     LAW   15000107 2015-01-01 01:41:40     NaN
# 4         186  2015   EPD     LAW   15000435 2015-01-01 15:09:21     NaN
# ...       ...   ...    ...     ...       ...                 ...     ...
# 76665  117254  2025   EPD     LAW   25327100 2025-12-31 17:12:02     NaN
# 76666  117265  2025   EPD     LAW   25327137 2025-12-31 17:56:18     NaN
# 76667  117284  2025   EPD     LAW   25327208 2025-12-31 20:23:13     NaN
# 76668  117295  2025   EPD     LAW   25327228 2025-12-31 20:50:01     NaN
# 76669  117301  2025   EPD     LAW   25327245 2025-12-31 21:11:50     NaN
#
#       callsource         nature closecode                closed_as  \
# 0          PHONE  CHECK WELFARE      ASST                 ASSISTED
# 1          PHONE  CHECK WELFARE      ASST                 ASSISTED
# 2          PHONE  CHECK WELFARE      UTL          UNABLE TO LOCATE
# 3          PHONE  CHECK WELFARE      ASST                 ASSISTED
# 4          PHONE  CHECK WELFARE      ASST                 ASSISTED
# ...          ...            ...       ...                      ...
# 76665      PHONE  CHECK WELFARE      DDIS  DISREGARDED BY DISPATCH
# 76666      PHONE  CHECK WELFARE      UTL          UNABLE TO LOCATE
# 76667      PHONE  CHECK WELFARE      WELC       WELFARE CHECK DONE
# 76668       W911  CHECK WELFARE      DIS                 DISREGARD
# 76669       W911  CHECK WELFARE      WELC       WELFARE CHECK DONE
#
#        secs_to_disp  secs_to_arrv  secs_to_close  disp  arrv priority  \
# 0             708.0        1094.0           1538     1     1        5
# 1            2402.0        2941.0           3594     1     1        5
# 2            1305.0        1524.0           1824     1     1        5
# 3             600.0         926.0           1285     1     1        5
# 4            3018.0        3605.0           4369     1     1        7
# ...             ...           ...            ...   ...   ...      ...
# 76665           NaN           NaN           4147     0     0        4
# 76666        5655.0        6292.0           8294     1     1        3
# 76667        2828.0        3001.0           3451     1     1        3
# 76668         354.0         740.0            818     1     1        3
# 76669        3433.0        4208.0           5682     1     1        3
#
#       primeunit  units_dispd  units_arrived  month  year Institution
# 0          3J79            1              1      1  2015     CAHOOTS
# 1          3J79            1              1      1  2015     CAHOOTS
# 2          5B44            1              1      1  2015         EPD
# 3          3J79            1              1      1  2015     CAHOOTS
# 4          3J79            1              1      1  2015     CAHOOTS
# ...         ...          ...            ...    ...   ...         ...
# 76665       NaN            0              0     12  2025     Neither
# 76666      4U72            2              2     12  2025         EPD
# 76667      5E56            2              2     12  2025         EPD
# 76668      4U72            2              2     12  2025         EPD
# 76669      6B36            1              1     12  2025         EPD
#
# [76251 rows x 23 columns]

# %%
welfare['service'].unique() #LAW is the only value, so can drop
# Out:
# array(['LAW '], dtype=object)

# %%
#dropping a few unneeded rows
welfare.drop(['index','agency','service','yr'],axis=1,inplace=True)
# Out:
# /var/folders/0y/gklqyv_101130y1ly46wc5wm0000gn/T/ipykernel_24977/200182458.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   welfare.drop(['index','agency','service','yr'],axis=1,inplace=True)

# %%
welfare.head()
# Out:
#     inci_id            calltime case_id callsource         nature closecode  \
# 0  15000003 2015-01-01 00:01:05     NaN      PHONE  CHECK WELFARE      ASST
# 1  15000052 2015-01-01 00:38:37     NaN      PHONE  CHECK WELFARE      ASST
# 2  15000092 2015-01-01 01:28:40     NaN      PHONE  CHECK WELFARE      UTL
# 3  15000107 2015-01-01 01:41:40     NaN      PHONE  CHECK WELFARE      ASST
# 4  15000435 2015-01-01 15:09:21     NaN      PHONE  CHECK WELFARE      ASST
#
#           closed_as  secs_to_disp  secs_to_arrv  secs_to_close  disp  arrv  \
# 0          ASSISTED         708.0        1094.0           1538     1     1
# 1          ASSISTED        2402.0        2941.0           3594     1     1
# 2  UNABLE TO LOCATE        1305.0        1524.0           1824     1     1
# 3          ASSISTED         600.0         926.0           1285     1     1
# 4          ASSISTED        3018.0        3605.0           4369     1     1
#
#   priority primeunit  units_dispd  units_arrived  month  year Institution
# 0        5      3J79            1              1      1  2015     CAHOOTS
# 1        5      3J79            1              1      1  2015     CAHOOTS
# 2        5      5B44            1              1      1  2015         EPD
# 3        5      3J79            1              1      1  2015     CAHOOTS
# 4        7      3J79            1              1      1  2015     CAHOOTS

# %%
welfare['Institution'].unique()
# Out:
# array(['CAHOOTS', 'EPD', 'Neither'], dtype=object)

# %%
welfare.to_csv("./data/welfare.csv")

# %% [markdown]
# -- End of data cleaning --
